# %%
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline

# %%
x = 6 * np.random.rand(200, 1) - 3
y = 0.8 * x**2 + 0.9 * x + 2 + np.random.randn(200, 1)

# %%
plt.plot(x, y, 'b.')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2, random_state=2)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.2793238259235463

# %%
plt.plot(x_train, lr.predict(x_train), color = 'r')
plt.plot(x, y, "b.")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
poly = PolynomialFeatures(degree=2)

x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.fit(x_test)

# %%
x_test_trans
# Out:
# PolynomialFeatures()

# %%
print(x_train[0])
print(x_train_trans[0])
# Out:
# [-0.9901282]
# [ 1.         -0.9901282   0.98035385]

# %%
lr = LinearRegression()
lr.fit(x_train_trans, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test_trans.reshape(1, -1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 y_pred = lr.predict(x_test_trans.reshape(1, -1))
#
# AttributeError: 'PolynomialFeatures' object has no attribute 'reshape'
